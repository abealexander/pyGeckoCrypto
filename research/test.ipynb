# %%
# import json
import requests

# %%
coin_id = "bitcoin"
currency = "USD"
API = f"https://api.coingecko.com/api/v3/simple/price?ids={coin_id}&vs_currencies={currency}"

# %%
r = requests.get(API)

# %%
r.json()
# Out:
# {'bitcoin': {'usd': 20205}}

# %%
r = requests.get("https://api.coingecko.com/api/v3/coins/list")

# %%
coin_ids = r.json()

# %%
coin_ids[0]['id']
# Out:
# '01coin'

# %%
for i in coin_ids:
    if i["id"] == "ethereum":
        print(i)
# Out:
# {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum'}

# %%
r = requests.get("https://api.coingecko.com/api/v3/simple/supported_vs_currencies")

# %%
r.json()
# Out:
# ['btc',
#  'eth',
#  'ltc',
#  'bch',
#  'bnb',
#  'eos',
#  'xrp',
#  'xlm',
#  'link',
#  'dot',
#  'yfi',
#  'usd',
#  'aed',
#  'ars',
#  'aud',
#  'bdt',
#  'bhd',
#  'bmd',
#  'brl',
#  'cad',
#  'chf',
#  'clp',
#  'cny',
#  'czk',
#  'dkk',
#  'eur',
#  'gbp',
#  'hkd',
#  'huf',
#  'idr',
#  'ils',
#  'inr',
#  'jpy',
#  'krw',
#  'kwd',
#  'lkr',
#  'mmk',
#  'mxn',
#  'myr',
#  'ngn',
#  'nok',
#  'nzd',
#  'php',
#  'pkr',
#  'pln',
#  'rub',
#  'sar',
#  'sek',
#  'sgd',
#  'thb',
#  'try',
#  'twd',
#  'uah',
#  'vef',
#  'vnd',
#  'zar',
#  'xdr',
#  'xag',
#  'xau',
#  'bits',
#  'sats']

# %%
import sys
sys.path.append('../src/')

# %%
from pyGeckoCrypto import get_current_price, check_coinID, request, check_currency, check_timestamp, get_hist_price_range

# %%
get_current_price("fantom", "usd")
# Out:
# 0.225452

# %%
check_coinID("Bitcoin")
# Out:
# True

# %%
check_coinID("ethereudsam")
# Out:
# False

# %%
check_currency("usd")
# Out:
# True

# %%
check_currency("inr")
# Out:
# True

# %%
check_currency("usdaa")
# Out:
# False

# %%
request(API)
# Out:
# {'bitcoin': {'usd': 20205}}

# %%
len(coin_ids)
# Out:
# 13191

# %%
request("https://api.coingecko.com/api/v3/simple/price?ids=ethereum&vs_currencies=inr")
# Out:
# {'ethereum': {'inr': 112388}}

# %%
request("https://api.coingecko.com/api/v3/simple/price?ids=fantom&vs_currencies=usd")
# Out:
# {'fantom': {'usd': 0.225481}}

# %%
type(request("https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range?vs_currency=usd&from=1661990400&to=1664582399"))
# Out:
# dict

# %%
import datetime
given_date = "1/1/2022"
formated_date = datetime.datetime.strptime(given_date,"%d/%m/%Y")
Unix_timestamp = datetime.datetime.timestamp(formated_date)
print("The Unix timestamp for the given input date is:")
print(Unix_timestamp)
# Out:
# The Unix timestamp for the given input date is:
# 1640975400.0

# %%
datetime.datetime.fromtimestamp(
        int("001209000")
    ).strftime('%Y-%m-%d')
# Out:
# '1970-01-15'

# %%
check_timestamp("1234-5678")
# Out:
# [2022-10-06 17:59:11,093: ERROR: api]: invalid literal for int() with base 10: '1234-5678'
# Traceback (most recent call last):
#   File "E:\Projects\pyGeckoCrypto\src\pyGeckoCrypto\api.py", line 90, in check_timestamp
#     if type(datetime.datetime.fromtimestamp(int(date)).strftime("%Y-%m-%d")) == str:
# ValueError: invalid literal for int() with base 10: '1234-5678'
# False

# %%
get_hist_price_range("bitcoin", "usd", "123", "1392577232")
# Out:
# {'prices': [[1367107200000, 135.3],
#   [1367193600000, 141.96],
#   [1367280000000, 135.3],
#   [1367366400000, 117.0],
#   [1367452800000, 103.43],
#   [1367539200000, 91.01],
#   [1367625600000, 111.25],
#   [1367712000000, 116.79],
#   [1367798400000, 118.33],
#   [1367884800000, 106.4],
#   [1367971200000, 112.64],
#   [1368057600000, 113.0],
#   [1368144000000, 118.78],
#   [1368230400000, 113.01],
#   [1368316800000, 114.713],
#   [1368403200000, 117.18],
#   [1368489600000, 114.5],
#   [1368576000000, 114.156],
#   [1368662400000, 115.5],
#   [1368748800000, 123.1],
#   [1368835200000, 123.88],
#   [1368921600000, 120.501],
#   [1369008000000, 122.58],
#   [1369094400000, 122.9],
#   [1369180800000, 123.0],
#   [1369267200000, 125.748],
#   [1369353600000, 131.7],
#   [1369440000000, 130.77],
#   [1369526400000, 134.6],
#   [1369612800000, 128.985],
#   [1369699200000, 129.179],
#   [1369785600000, 132.13],
#   [1369872000000, 127.401],
#   [1369958400000, 127.98],
# ...
